# %%
# 2-1 변수에 '철수'를 담기
k36_name='철수'
print(k36_name)

# 2-1 변수에 '영희'를 담기
k36_name='영희'
print(k36_name)
# Out:
# 철수
# 영희

# %%
# 2-2 새로운 변수를 정의할 때 반드시 변수에 값을 대입해야 함.
k36_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9dba024bc09c> in <cell line: 0>()
#       1 # 2-2 새로운 변수를 정의할 때 반드시 변수에 값을 대입해야 함.
# ----> 2 k36_score
#
# NameError: name 'k36_score' is not defined

# %%
# 2-3 변수의 이름에서 첫 글자는 문자 또는 밑줄 문자여야 한다.
2_k36_name='철수, 영희'
# Out:
#   File "<ipython-input-19-0bed2f52e794>", line 2
#     2_k36_name='철수, 영희'
#      ^
# SyntaxError: invalid decimal literal

# %%
# 2-4 상수처럼 사용하는 변수
PI=3.1415
GRAVITY=9.8

# %%
# 2-5 산술연산자
k36_a=11
k36_b=4

print('덧셈 결과', k36_a+k36_b)
print('뺄셈 결과', k36_a-k36_b)
print('곱셈 결과', k36_a*k36_b)
print('나눗셈 결과', k36_a/k36_b)
print('나눗셈 정수 몫', k36_a//k36_b)
print('나눗셈 나머지', k36_a%k36_b)
print('거듭제곱 결과', k36_a**k36_b)
# Out:
# 덧셈 결과 15
# 뺄셈 결과 7
# 곱셈 결과 44
# 나눗셈 결과 2.75
# 나눗셈 정수 몫 2
# 나눗셈 나머지 3
# 거듭제곱 결과 14641

# %%
# 2-6 관계 연산자
k36_a=11
k36_b=4

print(k36_a>k36_b)
print(k36_a>=k36_b)
print(k36_a<k36_b)
print(k36_a<=k36_b)

# 파이썬의 논리값은 True/Flase(대문자)
# Out:
# True
# True
# False
# False

# %%
# 2-7 논리 연산자
k36_a=True
k36_b=False
print(k36_a and k36_b)
print(k36_a or k36_b)
# Out:
# False
# True

# %%
# 2-8 멤버 연산자
k36_a=3
k36_B=[1,3,5,7,9]   # 리스트

print(k36_a in k36_B)
print(k36_a not in k36_B)
# Out:
# True
# False

# %%
# 파이썬의 연산자 사용
# 1. 반지름이 5.5인 원의 면적을 계산, 원주율은 3.14를 변수에 저장
k36_PI=3.14   # 원주율
k36_r=5.5     # 반지름
k36_circle=k36_r*k36_r*k36_PI   # 원의 넓이

print(k36_circle)
# Out:
# 94.985

# %%
# 2. 그림의 두 삼각형 A와 B의 면적이 같은지 판단하여 참 또는 거짓으로 출력
k36_a_h=4     # 삼각형 A의 높이
k36_a_w=10    # 삼각형 A의 밑변
k36_b_h=5     # 삼각형 B의 높이
k36_b_w=5     # 삼각형 B의 밑변
k36_A=k36_a_h*k36_a_w*(1/2)   # 삼각형 A의 넓이
k36_B=k36_b_h*k36_b_w*(1/2)   # 삼각형 B의 넓이

print(k36_A==k36_B)
# Out:
# False

# %%
# 3. 철수는 중간고사에서 국어 95점, 수학 88점, 영어 90점을 받았고,
#    과학 점수는 잊어 버렸지만 네 과목 평균 점수는 92점이었습니다. 철수의 과학 점수는 몇 점일까요?
k36_k=95    # 국어 점수
k36_m=88    # 수학 점수
k36_e=90    # 영어 점수
k36_ave=92  # 평균
k36_n=4     # 과목 수
k36_sc=k36_ave*k36_n-k36_k-k36_m-k36_e    # 과학점수=평균*과목수-국어점수-수학점수-영어점수

print(k36_sc)
# Out:
# 95
